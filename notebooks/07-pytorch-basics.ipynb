# %% [markdown]
# # PyTorch Basics
#
# This notebook explains the PyTorch training shape using NumPy so it remains runnable with the base requirements. Install PyTorch separately if you want to translate it.

# %%
import numpy as np

# Tensors are multidimensional arrays. Autograd libraries track operations on them.
x = np.array([[1.0, 2.0], [3.0, 4.0]])
w = np.array([[0.5], [-0.25]])
print(x @ w)

# %% [markdown]
# Mini exercise: rewrite the matrix multiplication as a manual loop to understand tensor shapes.
